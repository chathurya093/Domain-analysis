# %% [markdown]
# # Domain Analysis

# %%
#import the libraries
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("C:/Users/maaduchathurya/OneDrive/文档/crt techincal/Advertising.csv")
data.shape
# Out:
# (200, 5)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   Radio       200 non-null    float64
#  3   Newspaper   200 non-null    float64
#  4   Sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
data.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
data.tail()
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4

# %%
data.sample()
# Out:
#     Unnamed: 0     TV  Radio  Newspaper  Sales
# 42          43  293.6   27.7        1.8   20.7

# %%
data.isna()
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0         False  False  False      False  False
# 1         False  False  False      False  False
# 2         False  False  False      False  False
# 3         False  False  False      False  False
# 4         False  False  False      False  False
# ..          ...    ...    ...        ...    ...
# 195       False  False  False      False  False
# 196       False  False  False      False  False
# 197       False  False  False      False  False
# 198       False  False  False      False  False
# 199       False  False  False      False  False
#
# [200 rows x 5 columns]

# %%
sns.histplot(x=data['TV'],kde=True,bins=40)
# Out:
# <Axes: xlabel='TV', ylabel='Count'>

# %%
sns.histplot(x=data['Radio'],kde=True,bins=40)
# Out:
# <Axes: xlabel='Radio', ylabel='Count'>

# %%
sns.histplot(x=data['Newspaper'],kde=True,bins=40)
# Out:
# <Axes: xlabel='Newspaper', ylabel='Count'>

# %%
sns.histplot(x=data['Sales'],kde=True,bins=40)
# Out:
# <Axes: xlabel='Sales', ylabel='Count'>

# %%
sns.histplot(x=data['Unnamed: 0'],kde=True,bins=40)
# Out:
# <Axes: xlabel='Unnamed: 0', ylabel='Count'>

# %%
data['TV'].skew()#negative skewed
# Out:
# np.float64(-0.06985336213274573)

# %%
data['Unnamed: 0'].skew()#normal
# Out:
# np.float64(0.0)

# %%
data['Radio'].skew()#positive skewed
# Out:
# np.float64(0.09417463149664404)

# %%
data['Newspaper'].skew()
# Out:
# np.float64(0.8947204074986175)

# %%
data['Sales'].skew()
# Out:
# np.float64(0.4075714250767127)

# %% [markdown]
# # Insigths

# %% [raw]
# tv,newspaper,sales,columns has near values to normal distribution as (-0.07,0.09,0.40)which is near to the 0(normal distribution) that why we can
# consider it as normal distribution

# %%
sns.scatterplot(x=data['Sales'],y=data['TV'])  #positive relation due to left to right movement
# Out:
# <Axes: xlabel='Sales', ylabel='TV'>

# %%
sns.scatterplot(x=data['Sales'],y=data['Newspaper']) #random relation
# Out:
# <Axes: xlabel='Sales', ylabel='Newspaper'>

# %%
sns.scatterplot(x=data['Sales'],y=data['Radio']) #positive relation due to left to right movement
# Out:
# <Axes: xlabel='Sales', ylabel='Radio'>

# %%
sns.scatterplot(x=data['Sales'],y=data['Unnamed: 0']) #random relation

# %%
data.corr()
# Out:
#             Unnamed: 0        TV     Radio  Newspaper     Sales
# Unnamed: 0    1.000000  0.017715 -0.110680  -0.154944 -0.051616
# TV            0.017715  1.000000  0.054809   0.056648  0.782224
# Radio        -0.110680  0.054809  1.000000   0.354104  0.576223
# Newspaper    -0.154944  0.056648  0.354104   1.000000  0.228299
# Sales        -0.051616  0.782224  0.576223   0.228299  1.000000

# %% [markdown]
# # insights

# %%
unnamed/unnamed=strong postive
unnamed/tv=positive weak
unnamed/radio=negative weak
unnamed/newspaper=negative weak
unnamed/sales=negative weak

tv/unnamed=weak positive
tv/tv=postive strong
tv/radio=weak postive
tv/newspaper=positive weak
tv/sales=positive moderate

# %%
sns.heatmap(data.corr(),annot=True,cmap='Blues')
# Out:
# <Axes: >

# %%
sns.heatmap(data.corr(),annot=True,cmap='Reds')
# Out:
# <Axes: >

# %%
data.drop('Unnamed: 0',axis=1,inplace=True)# remove the column

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
x=data.drop('Sales',axis=1)
y=data.Sales

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
data.corr()
# Out:
#                  TV     Radio  Newspaper     Sales
# TV         1.000000  0.054809   0.056648  0.782224
# Radio      0.054809  1.000000   0.354104  0.576223
# Newspaper  0.056648  0.354104   1.000000  0.228299
# Sales      0.782224  0.576223   0.228299  1.000000

# %% [markdown]
# # simple linear regression

# %% [markdown]
# # TV

# %%
#step1: independent and dependent variable creation 
x=data[['TV']]# variables contains one feature
y=data.Sales#y is target

# %%
from sklearn .model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=4)

# %%
print(len(x_test))
print(len(x_train))
# Out:
# 40
# 160

# %%
#step3 creating model
from sklearn.linear_model import LinearRegression
LR=LinearRegression() #object creation
LR.fit(x_train,y_train) #training of linear regression
y_predict=LR.predict(x_test)

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error,root_mean_squared_error
r2score=r2_score(y_test,y_predict)
r2score
# Out:
# 0.46138746336817515

# %%
print("MSE :",mean_squared_error(y_test,y_predict))
print("MAE :",mean_absolute_error(y_test,y_predict))
print("MRSE :",root_mean_squared_error(y_test,y_predict))
# Out:
# MSE : 13.06226628830567
# MAE : 2.990565035759226
# MRSE : 3.6141757412037494

# %% [markdown]
# # Radio:

# %%
#step1: independent and dependent variable creation 
x=data[['Radio']]# variables contains one feature
y=data.Sales#y is target

# %%
from sklearn .model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=4)

# %%
print(len(x_test))
print(len(x_train))
# Out:
# 40
# 160

# %%
#step3 creating model
from sklearn.linear_model import LinearRegression
LR=LinearRegression() #object creation
LR.fit(x_train,y_train) #training of linear regression
y_predict=LR.predict(x_test)

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error,root_mean_squared_error
r2score=r2_score(y_test,y_predict)
r2score
# Out:
# 0.37864501183785726

# %%
print("MSE :",mean_squared_error(y_test,y_predict))
print("MAE :",mean_absolute_error(y_test,y_predict))
print("MRSE :",root_mean_squared_error(y_test,y_predict))
# Out:
# MSE : 15.068910882943161
# MAE : 3.268917036469783
# MRSE : 3.881869508747449

# %% [markdown]
# # Newspaper:

# %%
#step1: independent and dependent variable creation 
x=data[['Newspaper']]# variables contains one feature
y=data.Sales#y is target

# %%
from sklearn .model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=4)

# %%
print(len(x_test))
print(len(x_train))
# Out:
# 40
# 160

# %%
#step3 creating model
from sklearn.linear_model import LinearRegression
LR=LinearRegression() #object creation
LR.fit(x_train,y_train) #training of linear regression
y_predict=LR.predict(x_test)

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error,root_mean_squared_error
r2score=r2_score(y_test,y_predict)
r2score
# Out:
# -0.11728796161004906

# %%
print("MSE :",mean_squared_error(y_test,y_predict))
print("MAE :",mean_absolute_error(y_test,y_predict))
print("MRSE :",root_mean_squared_error(y_test,y_predict))
# Out:
# MSE : 27.096125475528662
# MAE : 3.992290912504232
# MRSE : 5.205393882841976

# %% [markdown]
# # Multi linear regression

# %%
#step1: independent and dependent variable creation 
x=data[['TV','Radio','Newspaper']]# variables contains one feature
y=data.Sales#y is target
x
# Out:
#         TV  Radio  Newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %%
from sklearn .model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=4)

# %%
print(len(x_test))
print(len(x_train))
# Out:
# 40
# 160

# %%
#step3 creating model
from sklearn.linear_model import LinearRegression
LR=LinearRegression() #object creation
LR.fit(x_train,y_train) #training of linear regression
y_predict=LR.predict(x_test)
print("R2 : ",r2_score(y_test,y_predict))
# Out:
# R2 :  0.9085774752313167

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error,root_mean_squared_error
r2score=r2_score(y_test,y_predict)
r2score
# Out:
# 0.9085774752313167

# %%
print("MSE :",mean_squared_error(y_test,y_predict))
print("MAE :",mean_absolute_error(y_test,y_predict))
print("MRSE :",root_mean_squared_error(y_test,y_predict))
# Out:
# MSE : 2.217151072541896
# MAE : 1.2114892606469103
# MRSE : 1.4890100982001082
